# %% [markdown]
# <a href="https://colab.research.google.com/github/ndegwaanth/Data_Preprocessing/blob/main/Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "/content/Life Expectancy Data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# missing value percentage
df.isna().sum() / df.shape[0] * 100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %%
df_num = df.select_dtypes(include=np.number)
df_cat = df.select_dtypes(include=['object'])

# %%
df_num.head()
# Out:
#    Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015              65.0            263.0             62     0.01
# 1  2014              59.9            271.0             64     0.01
# 2  2013              59.9            268.0             66     0.01
# 3  2012              59.5            272.0             69     0.01
# 4  2011              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df_cat.head()
# Out:
#        Country      Status
# 0  Afghanistan  Developing
# 1  Afghanistan  Developing
# 2  Afghanistan  Developing
# 3  Afghanistan  Developing
# 4  Afghanistan  Developing

# %%
df_num.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df_num.shape
# Out:
# (2938, 20)

# %%
df_cat.describe()
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %%
df_cat.shape
# Out:
# (2938, 2)

# %%
df_num.fillna(df_num.mean(), inplace=True)
df_cat.fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-33-bb50e2e9784a>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cat.fillna(method='ffill', inplace=True)

# %%
# concatinade both df_num and df_cat
df = pd.concat([df_num, df_cat], axis=1)
df.head()
# Out:
#    Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015              65.0            263.0             62     0.01
# 1  2014              59.9            271.0             64     0.01
# 2  2013              59.9            268.0             66     0.01
# 3  2012              59.5            272.0             69     0.01
# 4  2011              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    ...  Diphtheria    HIV/AIDS         GDP  Population   thinness  1-19 years  \
# ...

# %%
df.isna().sum()
# Out:
# Year                               0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# Country                            0
# Status                             0
# dtype: int64

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# cheking for the garbage values
for col in df.select_dtypes(include='object').columns:
  print(col)
  print(df[col].value_counts())
  print('-'*20)
# Out:
# Country
# Country
# Afghanistan              16
# Albania                  16
# Algeria                  16
# Angola                   16
# Antigua and Barbuda      16
#                          ..
# Monaco                    1
# Marshall Islands          1
# Saint Kitts and Nevis     1
# San Marino                1
# Tuvalu                    1
# Name: count, Length: 193, dtype: int64
# --------------------
# Status
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64
# --------------------

# %%
# removing spaces
for col in df.select_dtypes(include='object').columns:
  df[col] = df[col].str.strip()
  df[col] = df[col].replace('', np.nan)

# %%
df.replace('', np.nan, inplace=True)

# %%
# EDA for objects
for graph in df.select_dtypes(include='object').columns:
  plt.figure(figsize=(10, 5))
  sns.countplot(data=df, x=graph, order=df[graph].value_counts().index)
  plt.title(f'Distribution of {graph}')
  plt.xlabel(graph)
  plt.ylabel('Frequency')
  plt.xticks(rotation=90)
  plt.show()

# %%
# EDA for numeric
for graph in df.select_dtypes(include=np.number).columns:
  plt.figure(figsize=(10, 5))
  ax = sns.histplot(data=df, x=graph, kde=True)
  plt.title(f'Distribution of {graph}')
  plt.xlabel(graph)
  plt.ylabel('Frequency')

  ax.bar_label(ax.containers[0], label_type='edge', padding=3,
              bbox=dict(facecolor='white', alpha=0.7, edgecolor='gray'))

  plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling',
#        'Country', 'Status'],
#       dtype='object')

# %%
for i in ['Year', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
       'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
       ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
       ' thinness 5-9 years', 'Income composition of resources', 'Schooling',
       'Country', 'Status']:
       sns.scatterplot(data=df, x=i, y='Life expectancy ')
       plt.show()

# %%
s = df.select_dtypes(include='number').corr()
s
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.169623        -0.078861
# Life expectancy                  0.169623          1.000000        -0.696359
# Adult Mortality                 -0.078861         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196535         0.078747
# Alcohol                         -0.048168          0.391598        -0.190408
# percentage expenditure           0.031400          0.381791        -0.242814
# Hepatitis B                      0.089398          0.203771        -0.138591
# Measles                         -0.082493         -0.157574         0.031174
#  BMI                             0.108327          0.559255        -0.381449
# under-five deaths               -0.042937         -0.222503         0.094135
# Polio                            0.093820          0.461574        -0.272694
# ...

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(s, annot=True, cmap='coolwarm', fmt='.2f', linewidths=2)
plt.show()

# %%
for i in df.select_dtypes(include=['number', 'object']).columns:
  sns.boxplot(data=df, x=i)
  plt.show()

# %%
df_num_2 = df.select_dtypes(include='number').columns
df_num_2
# Out:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
def wisker(col):
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  return lower_bound, upper_bound

# %%
up, lb = wisker(df_num_2)
print(f"Upper Bounnd {up} : Lower Bound {lb} \n")
# Out:
# Upper Bounnd Year                               1.992000e+03
# Life expectancy                    4.460000e+01
# Adult Mortality                   -1.555000e+02
# infant deaths                     -3.300000e+01
# Alcohol                           -8.353750e+00
# percentage expenditure            -6.505879e+02
# Hepatitis B                        5.835115e+01
# Measles                           -5.403750e+02
#  BMI                              -3.565000e+01
# under-five deaths                 -4.200000e+01
# Polio                              4.950000e+01
# Total expenditure                 -7.000000e-02
# Diphtheria                         4.950000e+01
#  HIV/AIDS                         -9.500000e-01
# GDP                               -9.773520e+03
# Population                        -1.808277e+07
#  thinness  1-19 years             -6.650000e+00
#  thinness 5-9 years               -6.800000e+00
# Income composition of resources    1.026250e-01
# ...

# %%
def wisker(col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

for i in df_num_2:
    lw, up = wisker(i)
    df[i] = np.where(df[i] > up, up, df[i])
    df[i] = np.where(df[i] < lw, lw, df[i])

# %%
for i in df.select_dtypes(include='number').columns:
  sns.boxplot(data=df, x=i)
  plt.show()

# %%
dummy = pd.get_dummies(data=df, columns=['Country', 'Status'], drop_first=True)
dummy.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-1ea22830e8bd> in <cell line: 0>()
# ----> 1 dummy = pd.get_dummies(data=df, columns=['Country', 'Status'], drop_first=True)
#       2 dummy.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns
categorical_cols
# Out:
# Index(['Country', 'Status'], dtype='object')

# %%
df = pd.get_dummies(data=df, columns=categorical_cols, drop_first=True)
df.head()
# Out:
#      Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015.0              65.0            263.0           55.0     0.01
# 1  2014.0              59.9            271.0           55.0     0.01
# 2  2013.0              59.9            268.0           55.0     0.01
# 3  2012.0              59.5            272.0           55.0     0.01
# 4  2011.0              59.2            275.0           55.0     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0   900.625   19.1                70.0
# 1               73.523582         62.0   492.000   18.6                70.0
# 2               73.219243         64.0   430.000   18.1                70.0
# 3               78.184215         67.0   900.625   17.6                70.0
# 4                7.097109         68.0   900.625   17.2                70.0
#
#    ...  Country_United States of America  Country_Uruguay  Country_Uzbekistan  \
# ...

# %%
df.fit(df[categorical_cols])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-b2eb52233b81> in <cell line: 0>()
# ----> 1 df.fit(df[categorical_cols])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'fit'

# %%
encoded_data = ohe.transform(dummy[categorical_features]).toarray()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Columns: 213 entries, Year to Status_Developing
# dtypes: bool(193), float64(20)
# memory usage: 1012.9 KB
